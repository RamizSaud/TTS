# %%
import pandas as pd
from ai4bharat.transliteration import XlitEngine

# %%
df = pd.read_csv("data/metadata.txt",sep = "|")

# %%
ur_rm = pd.read_csv("urdu_to_roman.csv")
ur_rm = ur_rm.set_index('0')['1'].to_dict()

# %%
e = XlitEngine(src_script_type="indic", beam_width=10, rescore=False)
# Out:
# Downloading Multilingual model for transliteration
# MB100% (119.0 of 119.0) |################| Elapsed Time: 0:00:45 Time:  0:00:450003
# Succefully Downloaded to: /usr/local/lib/python3.8/dist-packages/ai4bharat/transliteration/transformer/models/indic2en/v1.0/model.zip
# Models downloaded to: /usr/local/lib/python3.8/dist-packages/ai4bharat/transliteration/transformer/models/indic2en/v1.0
# NOTE: When uninstalling this library, REMEMBER to delete the models manually
# Initializing Multilingual model for transliteration

# %%
def transliteration(row):
    sentence = row[1]
    words = sentence.split()
    translit = ""
    for word in words:
        try:
            translit += " " + ur_rm[word]
        except:
            translit += " " + e.translit_word(word, lang_code="ur", topk=1)[0]
    if row.name%1000 == 0:
        print(row.name)
    return translit.strip()

# %%
df['Text'] = df.apply(transliteration, axis=1)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000

# %%
df
# Out:
#                                                      File  \
# 0         ./data/wavs/current/fYocNaRmmDE&list___0__7.wav
# 1       ./data/wavs/current/fYocNaRmmDE&list___1001__1...
# 2       ./data/wavs/current/fYocNaRmmDE&list___1008__1...
# 3       ./data/wavs/current/fYocNaRmmDE&list___1015__1...
# 4       ./data/wavs/current/fYocNaRmmDE&list___1022__1...
# ...                                                   ...
# 115654  ./data/wavs/current/g-ZcuW4JOnE&list___973__98...
# 115655  ./data/wavs/current/g-ZcuW4JOnE&list___980__98...
# 115656  ./data/wavs/current/g-ZcuW4JOnE&list___987__99...
# 115657  ./data/wavs/current/g-ZcuW4JOnE&list___98__105...
# 115658  ./data/wavs/current/g-ZcuW4JOnE&list___994__10...
#
#                                                      Text
# 0                                         alsalam alaikum
# 1       chhat wazeh hui yeh vahi chhat thi jo is ne pi...
# 2       lekin tab woh safed thi ab woh mustard rangi t...
# 3       vahi commrah tha lekin dewaron ka rang sarmie ...
# 4       is ke hath se jadi naliyon main safed nahin ba...
# ...                                                   ...
# 115654  bharosah tha woh sanbhal lay ga is lamhay khai...
# 115655  ek sath aisi hai jas main har baat gunaah nahi...
# 115656  diktar qasim ne apni kursi se uth kar khushdil...
# 115657  jakday bethi rahi sab tareef is allah ki jas n...
# 115658  bhara sweater pahne chehray pah sanjida aur ba...
#
# [115659 rows x 2 columns]

# %%
df.to_csv("data/metadata_roman.txt", sep = "|", index = False)
